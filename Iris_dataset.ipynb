# %% [markdown]
# # Creator -> SARTHAK ARORA

# %% [markdown]
# # BEGINNER LEVEL TASK

# %%
#Importing Libraries for futhur work and as required.

# %% [markdown]
# # TASK-1: Iris Flowers Classification ML Project :
# This particular ML project is usually referred to as the “Hello World” of Machine Learning.
# The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data.
# Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.

# %% [markdown]
# # Dataset link : http://archive.ics.uci.edu/ml/machine-learning-databases/iris

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',names=["Sepal_Length_in_cm","Sepal_Width_in_cm","Petal_Length(cm)","Petal_Width_in_cm","Species_Flower"])
print(df)
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length(cm)  \
# 0                   5.1                3.5               1.4
# 1                   4.9                3.0               1.4
# 2                   4.7                3.2               1.3
# 3                   4.6                3.1               1.5
# 4                   5.0                3.6               1.4
# ..                  ...                ...               ...
# 145                 6.7                3.0               5.2
# 146                 6.3                2.5               5.0
# 147                 6.5                3.0               5.2
# 148                 6.2                3.4               5.4
# 149                 5.9                3.0               5.1
#
#      Petal_Width_in_cm  Species_Flower
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
df.shape       #determines the size and the matrix representation of the dataset.
df.head(10)
df.columns
df.info()    # Gives the whole information about the database.
df.isnull().sum()
df['Species_Flower'].unique()
df.describe()  #describes about the whole dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sepal_Length_in_cm  150 non-null    float64
#  1   Sepal_Width_in_cm   150 non-null    float64
#  2   Petal_Length(cm)    150 non-null    float64
#  3   Petal_Width_in_cm   150 non-null    float64
#  4   Species_Flower      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length(cm)  \
# count          150.000000         150.000000        150.000000
# mean             5.843333           3.054000          3.758667
# std              0.828066           0.433594          1.764420
# min              4.300000           2.000000          1.000000
# 25%              5.100000           2.800000          1.600000
# 50%              5.800000           3.000000          4.350000
# ...

# %% [markdown]
# # Data Visualiztion

# %%
sb.pairplot(df,hue="Species_Flower")

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
sb.scatterplot(x='Sepal_Length_in_cm',y='Petal_Length_in_cm',data=df,hue='Species_Flower',ax=ax1)
sb.scatterplot(x='Sepal_Width_in_cm',y='Petal_Width_in_cm',data=df,hue='Species_Flower',ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
# ----> 2 sb.scatterplot(x='Sepal_Length_in_cm',y='Petal_Length_in_cm',data=df,hue='Species_Flower',ax=ax1)
#       3 sb.scatterplot(x='Sepal_Width_in_cm',y='Petal_Width_in_cm',data=df,hue='Species_Flower',ax=ax2)
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
# ...

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,5,1)
sb.boxplot(data=df,y='Sepal_Length_in_cm', color='black')
plt.subplot(1,5,2)
sb.boxplot(data=df,y='Sepal_Width_in_cm',color='red')
plt.subplot(1,5,3)
sb.boxplot(data=df,y='Petal_Width_in_cm',color='magenta')
plt.subplot(1,5,4)
sb.boxplot(data=df,y='Petal_Width_in_cm',color='blue')

plt.figure(figsize=(8,5))
sb.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# C:\Users\saart\AppData\Local\Temp\ipykernel_5164\4192814529.py:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df.corr(), annot=True)

# %% [markdown]
# # Building the model for training and then testing it for furthur.

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Species_Flower'] = lb.fit_transform = (df['Species_Flower'])
df.head(15)
# Out:
#     Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length(cm)  \
# 0                  5.1                3.5               1.4
# 1                  4.9                3.0               1.4
# 2                  4.7                3.2               1.3
# 3                  4.6                3.1               1.5
# 4                  5.0                3.6               1.4
# 5                  5.4                3.9               1.7
# 6                  4.6                3.4               1.4
# 7                  5.0                3.4               1.5
# 8                  4.4                2.9               1.4
# 9                  4.9                3.1               1.5
# 10                 5.4                3.7               1.5
# 11                 4.8                3.4               1.6
# 12                 4.8                3.0               1.4
# 13                 4.3                3.0               1.1
# 14                 5.8                4.0               1.2
#
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['Species_Flower'])
Y = df['Species_Flower']
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.4)

# %% [markdown]
# # Logistic-Regression

# %%
# Initialize a Logistic Regression
lr= LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)

#Calculating the predictions and sums
y_pred=lr.predict(x_test)
score=accuracy_score(y_test,y_pred)

def report(model):
    pre=model.predict(x_test)
    print(classification_report(pre,y_test))
    plot_confusion_matrix(model,x_test,y_test)

# %%
# 2. Linear-SVC(Scalable Vector Graphics).

sa= SVC()
sa.fit(x_train,y_train)
J_sa=LinearSVC()
J_sa.fit(x_train,y_train)

y_pred=J_sa.predict(x_test)
score=accuracy_score(y_test,y_pred)
print("Linear-SVC")
report(J_sa)
print('Linear SVC')
report(J_sa)
print('Accuracy: {round(score*100,2)}%')
# Out:
# Linear-SVC
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.95      0.91      0.93        23
#  Iris-virginica       0.90      0.95      0.92        19
#
#        accuracy                           0.95        60
#       macro avg       0.95      0.95      0.95        60
#    weighted avg       0.95      0.95      0.95        60
# C:\Users\saart\anaconda3\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       9 score=accuracy_score(y_test,y_pred)
#      10 print("Linear-SVC")
# ---> 11 report(J_sa)
#      12 print('Linear SVC')
#      13 report(J_sa)
#
# Cell In[23], line 12, in report(model)
# ...

# %%
# Initialize a Logistic Regression
lr= LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)

#Calculating the predictions and sums
y_pred=lr.predict(x_test)
score=accuracy_score(y_test,y_pred)

def report(model):
    pre=model.predict(x_test)
    print(classification_report(pre,y_test))
    plot_confusion_matrix(model,x_test,y_test)

# %%
print("LOGISTIC-REGRESSION")
report(lr)
print('Accuracy: {round(score*100,2)}%')
# Out:
# LOGISTIC-REGRESSION
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.95      0.91      0.93        23
#  Iris-virginica       0.90      0.95      0.92        19
#
#        accuracy                           0.95        60
#       macro avg       0.95      0.95      0.95        60
#    weighted avg       0.95      0.95      0.95        60
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 print("LOGISTIC-REGRESSION")
# ----> 2 report(lr)
#       3 print('Accuracy: {round(score*100,2)}%')
#
# Cell In[28], line 12, in report(model)
#      10 pre=model.predict(x_test)
#      11 print(classification_report(pre,y_test))
# ---> 12 plot_confusion_matrix(model,x_test,y_test)
#
# NameError: name 'plot_confusion_matrix' is not defined

# %%
actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
print("LOGISTIC-REGRESSION")
report(lr)
print('Accuracy: {round(score*100,2)}%')
# Out:
# LOGISTIC-REGRESSION
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.95      0.91      0.93        23
#  Iris-virginica       0.90      0.95      0.92        19
#
#        accuracy                           0.95        60
#       macro avg       0.95      0.95      0.95        60
#    weighted avg       0.95      0.95      0.95        60
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 print("LOGISTIC-REGRESSION")
# ----> 2 report(lr)
#       3 print('Accuracy: {round(score*100,2)}%')
#
# Cell In[28], line 12, in report(model)
#      10 pre=model.predict(x_test)
#      11 print(classification_report(pre,y_test))
# ---> 12 plot_confusion_matrix(model,x_test,y_test)
#
# NameError: name 'plot_confusion_matrix' is not defined

# %% [markdown]
# # 2. Linear-SVC(Scalable Vector Graphics).

# %%
sa= SVC()
sa.fit(x_train,y_train)
J_sa=LinearSVC()
J_sa.fit(x_train,y_train)

y_pred=J_sa.predict(x_test)
score=accuracy_score(y_test,y_pred)
print("Linear-SVC")
print('Accuracy: {round(score*100,2)}%')
# Out:
# Linear-SVC
# Accuracy: {round(score*100,2)}%
# C:\Users\saart\anaconda3\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# # 3. (DTC)->Decision Tree Classifier

# %%
DTC = DecisionTreeClassifier(max_depth=3, random_state=42)
DTC=DTC.fit(x_train,y_train)
y_pred=DTC.predict(x_test)
score=accuracy_score(y_test,y_pred)
print('Decision Tree Classifier')
report(DTC)
print('Accuracy: {round(score*100,2)}%')
# Out:
# Decision Tree Classifier
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.95      0.88      0.91        24
#  Iris-virginica       0.85      0.94      0.89        18
#
#        accuracy                           0.93        60
#       macro avg       0.93      0.94      0.94        60
#    weighted avg       0.94      0.93      0.93        60
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       4 score=accuracy_score(y_test,y_pred)
#       5 print('Decision Tree Classifier')
# ----> 6 report(DTC)
#       7 print('Accuracy: {round(score*100,2)}%')
#
# Cell In[28], line 12, in report(model)
#      10 pre=model.predict(x_test)
#      11 print(classification_report(pre,y_test))
# ---> 12 plot_confusion_matrix(model,x_test,y_test)
#
# ...

# %% [markdown]
# # 4. KNN-> (K-Nearest Neighbors Algorithm)

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
KNN.fit(x_train, y_train)
y_pred=KNN.predict(x_test)
score=accuracy_score(y_test,y_pred)
print('KNN')
report(KNN)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# KNN
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       1.00      0.85      0.92        26
#  Iris-virginica       0.80      1.00      0.89        16
#
#        accuracy                           0.93        60
#       macro avg       0.93      0.95      0.94        60
#    weighted avg       0.95      0.93      0.93        60
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 6
#       4 score=accuracy_score(y_test,y_pred)
#       5 print('KNN')
# ----> 6 report(KNN)
#       7 print(f'Accuracy: {round(score*100,2)}%')
#
# Cell In[28], line 12, in report(model)
#      10 pre=model.predict(x_test)
#      11 print(classification_report(pre,y_test))
# ---> 12 plot_confusion_matrix(model,x_test,y_test)
#
# NameError: name 'plot_confusion_matrix' is not defined
